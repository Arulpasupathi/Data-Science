# %%
print('hello i am started to learn streamlit')
# Out:
# hello i am started to learn streamlit

# %%
import streamlit as st

# %%
import streamlit as st

st.header('Welcome to Streamlit')
if st.button('Click here'):
    st.success('You clicked here')
# Out:
# 2026-06-20 15:53:22.182 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-20 15:53:23.810
# ...
#   command:
#
#     streamlit run C:\Users\HP\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-06-20 15:53:23.821 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-20 15:53:23.825 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-20 15:53:23.828 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-20 15:53:23.829 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
